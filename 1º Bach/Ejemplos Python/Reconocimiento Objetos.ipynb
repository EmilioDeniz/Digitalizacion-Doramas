# %% [markdown]
# #Paquetes necesarios

# %%
import cv2  
import math 

from ultralytics import YOLO

# %% [markdown]
# Reconocimiento de poses

# %%
# Carga del modelo
#model = YOLO('yolo11n.pt')  # Contenedores
#model = YOLO('yolo11n-seg.pt')  # Máscaras
model = YOLO('yolo11n-pose.pt')  # Pose

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    
    if not ret:
        print("Error al capturar la imagen desde la cámara.")
        break

    results = model(frame)

    frame_with_detections = results[0].plot()  

    cv2.imshow("Detección en tiempo real", frame_with_detections)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# Reconocimiento de objetos en una imagen

# %%
# Carga del modelo, descarga en disco si no está presente en la carpeta
model = YOLO('yolo11n.pt') #Contenedores

# Etiqueta de las distintas clases
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


# Captura desde la webcam
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, img = vid.read()
  
    # si hay imagen válida
    if ret:  
        # Detecta en la imagen
        results = model(img, stream=True)
        
        # Para cada detección
        for r in results:
            boxes = r.boxes

            for box in boxes:
                # Contenedor
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values
                
                # Confianza
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confianza --->",confidence)

                # Clase
                cls = int(box.cls[0])
                print("Clase -->", classNames[cls])

                # Convierte identificador numérico de clase a un color RGB
                escala = int((cls / len(classNames)) * 255 * 3)
                if escala >= 255*2:
                    R = 255
                    G = 255
                    B = escala - 255*2
                else:
                    if escala >= 255:
                        R = 255
                        G = escala - 255
                        B = 0
                    else:
                        R = escala
                        G = 0
                        B = 0

                # Dibuja el contenedor y clase
                cv2.rectangle(img, (x1, y1), (x2, y2), (R, G, B), 3)
                cv2.putText(img, classNames[cls] , [x1, y1], cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, B), 2)

        # Muestra fotograma
        cv2.imshow('Vid', img)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# Seguimiento de objetos que reconoce

# %%
from collections import defaultdict

# Carga del modelo, descarga en disco si no está presente en la carpeta
model = YOLO('yolo11n.pt') #Contenedores

# Etiqueta de las distintas clases
classNames = ["person", "bicycle", "car"]


# Captura desde la webcam
vid = cv2.VideoCapture(0)
track_history = defaultdict(lambda: [])
  
while(True):      
    # fotograma a fotograma
    ret, img = vid.read()
  
    # si hay imagen válida
    if ret:  
        # Seguimiento, con persistencia entre fotogramas
        results = model.track(img, persist=True, classes = [0,1,2])

        if 0:
            if results is not None:
                print(results[0])
                boxes = results[0].boxes.xywh.cpu()
                track_ids = results[0].boxes.id.int().cpu().tolist()
                annotated_frame = results[0].plot()
                for box, track_id in zip(boxes, track_ids):
                    x, y, w, h = box
                    track = track_history[track_id]
                    track.append((float(x), float(y)))
                    if len(track) > 30:
                        track.pop(0)
                    points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                    cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)
                cv2.imshow("YOLO11 Tracking", annotated_frame)
                if cv2.waitKey(1) & 0xFF == ord("q"):
                    break
        

        
        # Para cada detección
        for r in results:
            boxes = r.boxes

            for box in boxes:
                # Contenedor
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

                #Etiqueta de seguimiento
                if box.id is not None:
                    track_id = str(int(box.id[0].tolist()))
                else:
                    track_id = ''
                
                # Confianza
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confianza --->",confidence)

                # Clase
                cls = int(box.cls[0])
                print("Clase -->", classNames[cls])

                # Convierte identificador numérico de clase a un color RGB
                escala = int((cls / len(classNames)) * 255 * 3)
                if escala >= 255*2:
                    R = 255
                    G = 255
                    B = escala - 255*2
                else:
                    if escala >= 255:
                        R = 255
                        G = escala - 255
                        B = 0
                    else:
                        R = escala
                        G = 0
                        B = 0

                # Dibuja el contenedor y clase
                cv2.rectangle(img, (x1, y1), (x2, y2), (R, G, B), 3)
                cv2.putText(img, track_id + ' ' + classNames[cls] , [x1, y1], cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, B), 2)

        # Muestra fotograma
        cv2.imshow('Vid', img)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 23.4ms
# Speed: 1.3ms preprocess, 23.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.81
# Clase --> person
#
# 0: 480x640 1 person, 26.0ms
# Speed: 1.0ms preprocess, 26.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 23.5ms
# Speed: 0.7ms preprocess, 23.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.86
# Clase --> person
#
# 0: 480x640 1 person, 24.4ms
# Speed: 0.7ms preprocess, 24.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 21.8ms
# Speed: 0.7ms preprocess, 21.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 23.0ms
# Speed: 0.6ms preprocess, 23.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 24.2ms
# Speed: 0.6ms preprocess, 24.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 22.5ms
# Speed: 0.6ms preprocess, 22.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 22.4ms
# Speed: 0.6ms preprocess, 22.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 22.5ms
# Speed: 0.5ms preprocess, 22.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 22.4ms
# Speed: 0.6ms preprocess, 22.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 22.8ms
# Speed: 0.5ms preprocess, 22.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.86
# Clase --> person
#
# 0: 480x640 1 person, 21.9ms
# Speed: 0.5ms preprocess, 21.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.86
# Clase --> person
#
# 0: 480x640 1 person, 23.0ms
# Speed: 0.5ms preprocess, 23.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 24.2ms
# Speed: 0.6ms preprocess, 24.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.86
# Clase --> person
#
# 0: 480x640 1 person, 21.3ms
# Speed: 0.5ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.84
# Clase --> person
#
# 0: 480x640 1 person, 21.9ms
# Speed: 0.5ms preprocess, 21.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.81
# Clase --> person
#
# 0: 480x640 1 person, 22.7ms
# Speed: 0.6ms preprocess, 22.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.77
# Clase --> person
#
# 0: 480x640 1 person, 22.4ms
# Speed: 0.6ms preprocess, 22.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.8
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.5ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 22.1ms
# Speed: 0.6ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 24.7ms
# Speed: 0.6ms preprocess, 24.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.6ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.9ms
# Speed: 0.5ms preprocess, 21.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 22.6ms
# Speed: 0.6ms preprocess, 22.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 19.1ms
# Speed: 0.5ms preprocess, 19.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.78
# Clase --> person
#
# 0: 480x640 1 person, 24.2ms
# Speed: 0.6ms preprocess, 24.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.76
# Clase --> person
#
# 0: 480x640 1 person, 24.0ms
# Speed: 0.7ms preprocess, 24.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.76
# Clase --> person
#
# 0: 480x640 1 person, 23.5ms
# Speed: 0.6ms preprocess, 23.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.72
# Clase --> person
#
# 0: 480x640 1 person, 22.7ms
# Speed: 0.5ms preprocess, 22.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.66
# Clase --> person
#
# 0: 480x640 1 person, 23.9ms
# Speed: 0.7ms preprocess, 23.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.7
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.6ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.74
# Clase --> person
#
# 0: 480x640 1 person, 22.6ms
# Speed: 0.5ms preprocess, 22.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.75
# Clase --> person
#
# 0: 480x640 1 person, 22.6ms
# Speed: 0.6ms preprocess, 22.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.81
# Clase --> person
#
# 0: 480x640 1 person, 22.0ms
# Speed: 0.6ms preprocess, 22.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.78
# Clase --> person
#
# 0: 480x640 1 person, 20.2ms
# Speed: 0.7ms preprocess, 20.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.85
# Clase --> person
#
# 0: 480x640 1 person, 21.4ms
# Speed: 0.6ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.85
# Clase --> person
#
# 0: 480x640 1 person, 23.3ms
# Speed: 0.5ms preprocess, 23.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.85
# Clase --> person
#
# 0: 480x640 1 person, 22.0ms
# Speed: 0.5ms preprocess, 22.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 23.5ms
# Speed: 0.6ms preprocess, 23.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 22.0ms
# Speed: 0.5ms preprocess, 22.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.82
# Clase --> person
#
# 0: 480x640 1 person, 23.5ms
# Speed: 0.6ms preprocess, 23.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 23.6ms
# Speed: 0.5ms preprocess, 23.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.4ms
# Speed: 0.5ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.6ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 22.4ms
# Speed: 0.6ms preprocess, 22.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 21.3ms
# Speed: 0.7ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 23.0ms
# Speed: 0.6ms preprocess, 23.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 22.8ms
# Speed: 0.6ms preprocess, 22.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 21.4ms
# Speed: 0.6ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 20.8ms
# Speed: 0.5ms preprocess, 20.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 23.6ms
# Speed: 0.6ms preprocess, 23.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 21.6ms
# Speed: 0.5ms preprocess, 21.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 22.1ms
# Speed: 0.6ms preprocess, 22.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 21.4ms
# Speed: 0.5ms preprocess, 21.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 23.1ms
# Speed: 0.6ms preprocess, 23.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 22.0ms
# Speed: 0.5ms preprocess, 22.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 21.2ms
# Speed: 0.7ms preprocess, 21.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 22.0ms
# Speed: 0.5ms preprocess, 22.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.5ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.95
# Clase --> person
#
# 0: 480x640 1 person, 23.4ms
# Speed: 0.6ms preprocess, 23.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.5ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 24.1ms
# Speed: 0.7ms preprocess, 24.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 24.1ms
# Speed: 0.6ms preprocess, 24.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 23.9ms
# Speed: 0.6ms preprocess, 23.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 21.4ms
# Speed: 0.5ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.95
# Clase --> person
#
# 0: 480x640 1 person, 23.7ms
# Speed: 0.5ms preprocess, 23.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.95
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.5ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 23.5ms
# Speed: 0.5ms preprocess, 23.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 28.2ms
# Speed: 0.5ms preprocess, 28.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 23.0ms
# Speed: 0.5ms preprocess, 23.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 22.3ms
# Speed: 0.6ms preprocess, 22.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.8ms
# Speed: 0.5ms preprocess, 21.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 22.4ms
# Speed: 0.6ms preprocess, 22.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 24.3ms
# Speed: 0.6ms preprocess, 24.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 22.1ms
# Speed: 0.5ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 23.5ms
# Speed: 0.5ms preprocess, 23.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.6ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 24.7ms
# Speed: 0.6ms preprocess, 24.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.8ms
# Speed: 0.6ms preprocess, 21.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 21.5ms
# Speed: 0.5ms preprocess, 21.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 23.7ms
# Speed: 0.6ms preprocess, 23.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 23.1ms
# Speed: 0.5ms preprocess, 23.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.8ms
# Speed: 0.5ms preprocess, 21.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 23.9ms
# Speed: 0.5ms preprocess, 23.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.5ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 23.3ms
# Speed: 0.5ms preprocess, 23.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 22.0ms
# Speed: 0.5ms preprocess, 22.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 23.5ms
# Speed: 0.5ms preprocess, 23.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 16.9ms
# Speed: 0.6ms preprocess, 16.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 22.1ms
# Speed: 0.6ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 22.4ms
# Speed: 0.6ms preprocess, 22.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 24.1ms
# Speed: 0.5ms preprocess, 24.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 21.3ms
# Speed: 0.5ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 22.4ms
# Speed: 0.6ms preprocess, 22.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 22.6ms
# Speed: 0.5ms preprocess, 22.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 25.0ms
# Speed: 0.6ms preprocess, 25.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 21.8ms
# Speed: 0.6ms preprocess, 21.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 23.5ms
# Speed: 0.5ms preprocess, 23.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 21.8ms
# Speed: 0.6ms preprocess, 21.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 16.2ms
# Speed: 0.4ms preprocess, 16.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 22.2ms
# Speed: 0.5ms preprocess, 22.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 20.8ms
# Speed: 0.5ms preprocess, 20.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 21.5ms
# Speed: 0.5ms preprocess, 21.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.1ms
# Speed: 0.5ms preprocess, 21.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.9ms
# Speed: 0.6ms preprocess, 21.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.1ms
# Speed: 0.6ms preprocess, 21.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 20.3ms
# Speed: 0.4ms preprocess, 20.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 21.4ms
# Speed: 0.6ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 20.6ms
# Speed: 0.6ms preprocess, 20.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 19.5ms
# Speed: 0.6ms preprocess, 19.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 21.6ms
# Speed: 0.6ms preprocess, 21.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.5ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 21.9ms
# Speed: 0.5ms preprocess, 21.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 21.9ms
# Speed: 0.5ms preprocess, 21.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 21.1ms
# Speed: 0.6ms preprocess, 21.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 23.1ms
# Speed: 0.6ms preprocess, 23.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 22.1ms
# Speed: 0.6ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 20.7ms
# Speed: 0.6ms preprocess, 20.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 23.6ms
# Speed: 0.5ms preprocess, 23.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 21.4ms
# Speed: 0.5ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 23.0ms
# Speed: 0.5ms preprocess, 23.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 22.1ms
# Speed: 0.5ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.6ms
# Speed: 0.5ms preprocess, 21.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 23.2ms
# Speed: 0.5ms preprocess, 23.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.0ms
# Speed: 0.5ms preprocess, 21.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 24.7ms
# Speed: 0.9ms preprocess, 24.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.86
# Clase --> person
#
# 0: 480x640 1 person, 21.5ms
# Speed: 0.5ms preprocess, 21.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.86
# Clase --> person
#
# 0: 480x640 1 person, 24.4ms
# Speed: 0.6ms preprocess, 24.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 21.5ms
# Speed: 0.5ms preprocess, 21.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.83
# Clase --> person
#
# 0: 480x640 1 person, 23.3ms
# Speed: 0.5ms preprocess, 23.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.85
# Clase --> person
#
# 0: 480x640 1 person, 21.2ms
# Speed: 0.5ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 22.3ms
# Speed: 0.7ms preprocess, 22.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 23.1ms
# Speed: 0.5ms preprocess, 23.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 24.6ms
# Speed: 0.6ms preprocess, 24.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.8ms
# Speed: 0.6ms preprocess, 21.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 21.2ms
# Speed: 0.5ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 22.8ms
# Speed: 0.5ms preprocess, 22.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 21.2ms
# Speed: 0.6ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.6ms preprocess, 21.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.86
# Clase --> person
#
# 0: 480x640 1 person, 21.9ms
# Speed: 0.6ms preprocess, 21.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 21.0ms
# Speed: 0.6ms preprocess, 21.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.6ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 23.0ms
# Speed: 0.5ms preprocess, 23.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.85
# Clase --> person
#
# 0: 480x640 1 person, 23.5ms
# Speed: 0.6ms preprocess, 23.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.84
# Clase --> person
#
# 0: 480x640 1 person, 21.6ms
# Speed: 0.5ms preprocess, 21.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 21.1ms
# Speed: 0.6ms preprocess, 21.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.3ms
# Speed: 0.5ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 22.9ms
# Speed: 0.5ms preprocess, 22.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.86
# Clase --> person
#
# 0: 480x640 1 person, 21.2ms
# Speed: 0.5ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 21.3ms
# Speed: 0.6ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 23.2ms
# Speed: 0.5ms preprocess, 23.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.86
# Clase --> person
#
# 0: 480x640 1 person, 21.2ms
# Speed: 0.5ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.82
# Clase --> person
#
# 0: 480x640 1 person, 21.0ms
# Speed: 0.5ms preprocess, 21.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.81
# Clase --> person
#
# 0: 480x640 1 person, 21.3ms
# Speed: 0.5ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.81
# Clase --> person
#
# 0: 480x640 1 person, 20.8ms
# Speed: 0.5ms preprocess, 20.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.75
# Clase --> person
#
# 0: 480x640 1 person, 21.0ms
# Speed: 0.6ms preprocess, 21.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.84
# Clase --> person
#
# 0: 480x640 1 person, 21.1ms
# Speed: 0.5ms preprocess, 21.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.69
# Clase --> person
#
# 0: 480x640 1 person, 22.6ms
# Speed: 0.6ms preprocess, 22.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.83
# Clase --> person
#
# 0: 480x640 1 person, 23.9ms
# Speed: 0.6ms preprocess, 23.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.83
# Clase --> person
#
# 0: 480x640 1 person, 24.0ms
# Speed: 0.6ms preprocess, 24.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.73
# Clase --> person
#
# 0: 480x640 1 person, 21.5ms
# Speed: 0.5ms preprocess, 21.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.83
# Clase --> person
#
# 0: 480x640 1 person, 20.6ms
# Speed: 0.6ms preprocess, 20.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 23.4ms
# Speed: 0.6ms preprocess, 23.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 24.5ms
# Speed: 0.5ms preprocess, 24.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.83
# Clase --> person
#
# 0: 480x640 1 person, 22.4ms
# Speed: 0.5ms preprocess, 22.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.83
# Clase --> person
#
# 0: 480x640 1 person, 23.4ms
# Speed: 0.6ms preprocess, 23.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.6ms preprocess, 21.7ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 22.3ms
# Speed: 0.6ms preprocess, 22.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 24.0ms
# Speed: 0.6ms preprocess, 24.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 24.4ms
# Speed: 0.6ms preprocess, 24.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.5ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 23.7ms
# Speed: 0.5ms preprocess, 23.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 21.9ms
# Speed: 0.6ms preprocess, 21.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 27.5ms
# Speed: 0.5ms preprocess, 27.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 23.1ms
# Speed: 0.6ms preprocess, 23.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 22.1ms
# Speed: 0.6ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 21.0ms
# Speed: 0.5ms preprocess, 21.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 21.1ms
# Speed: 0.5ms preprocess, 21.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 22.4ms
# Speed: 0.6ms preprocess, 22.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 23.7ms
# Speed: 0.6ms preprocess, 23.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 22.1ms
# Speed: 0.6ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 22.0ms
# Speed: 0.5ms preprocess, 22.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.95
# Clase --> person
#
# 0: 480x640 1 person, 21.0ms
# Speed: 0.5ms preprocess, 21.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.95
# Clase --> person
#
# 0: 480x640 1 person, 22.1ms
# Speed: 0.5ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 21.6ms
# Speed: 0.5ms preprocess, 21.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 21.5ms
# Speed: 0.7ms preprocess, 21.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.94
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.5ms preprocess, 21.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.95
# Clase --> person
#
# 0: 480x640 1 person, 23.9ms
# Speed: 0.6ms preprocess, 23.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.93
# Clase --> person
#
# 0: 480x640 1 person, 21.9ms
# Speed: 0.6ms preprocess, 21.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.92
# Clase --> person
#
# 0: 480x640 1 person, 20.8ms
# Speed: 0.6ms preprocess, 20.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 22.8ms
# Speed: 0.5ms preprocess, 22.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 21.7ms
# Speed: 0.5ms preprocess, 21.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 21.6ms
# Speed: 0.6ms preprocess, 21.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 24.0ms
# Speed: 0.6ms preprocess, 24.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 22.6ms
# Speed: 0.6ms preprocess, 22.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 22.3ms
# Speed: 0.6ms preprocess, 22.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 23.1ms
# Speed: 0.6ms preprocess, 23.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 24.3ms
# Speed: 0.6ms preprocess, 24.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.86
# Clase --> person
#
# 0: 480x640 1 person, 21.1ms
# Speed: 0.5ms preprocess, 21.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.87
# Clase --> person
#
# 0: 480x640 1 person, 21.5ms
# Speed: 0.6ms preprocess, 21.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.3ms
# Speed: 0.6ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.3ms
# Speed: 0.5ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.0ms
# Speed: 0.5ms preprocess, 21.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 23.7ms
# Speed: 0.6ms preprocess, 23.7ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.3ms
# Speed: 0.6ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 21.0ms
# Speed: 0.5ms preprocess, 21.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 22.1ms
# Speed: 0.5ms preprocess, 22.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.6ms
# Speed: 0.5ms preprocess, 21.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.0ms
# Speed: 0.5ms preprocess, 21.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 22.5ms
# Speed: 0.6ms preprocess, 22.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 24.0ms
# Speed: 0.6ms preprocess, 24.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.91
# Clase --> person
#
# 0: 480x640 1 person, 23.4ms
# Speed: 0.5ms preprocess, 23.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 23.0ms
# Speed: 0.6ms preprocess, 23.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 23.3ms
# Speed: 0.5ms preprocess, 23.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.4ms
# Speed: 0.6ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 22.1ms
# Speed: 0.6ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.8ms
# Speed: 0.6ms preprocess, 21.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.5ms
# Speed: 0.5ms preprocess, 21.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.9ms
# Speed: 0.7ms preprocess, 21.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 23.4ms
# Speed: 0.6ms preprocess, 23.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 23.5ms
# Speed: 0.5ms preprocess, 23.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
#
# 0: 480x640 1 person, 23.7ms
# Speed: 0.6ms preprocess, 23.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.9ms
# Speed: 0.6ms preprocess, 21.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.8ms
# Speed: 0.6ms preprocess, 21.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 23.0ms
# Speed: 0.5ms preprocess, 23.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 15.6ms
# Speed: 0.4ms preprocess, 15.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 22.2ms
# Speed: 0.6ms preprocess, 22.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.4ms
# Speed: 0.5ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.6ms
# Speed: 0.6ms preprocess, 21.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 22.4ms
# Speed: 0.6ms preprocess, 22.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 23.0ms
# Speed: 0.6ms preprocess, 23.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 23.0ms
# Speed: 0.6ms preprocess, 23.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.9
# Clase --> person
#
# 0: 480x640 1 person, 21.2ms
# Speed: 0.5ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 21.6ms
# Speed: 0.5ms preprocess, 21.6ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 22.1ms
# Speed: 0.5ms preprocess, 22.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 22.0ms
# Speed: 0.7ms preprocess, 22.0ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.89
# Clase --> person
#
# 0: 480x640 1 person, 23.1ms
# Speed: 0.5ms preprocess, 23.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Confianza ---> 0.88
# Clase --> person
